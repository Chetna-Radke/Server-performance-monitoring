# %%
from operator import index

import pandas as pd
from numpy.conftest import dtype

# %%
s = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
#
# NameError: name 'pd' is not defined

# %%
class Names:
    pass
class marks:
    pass


d= pd.DataFrame({Names: ["janvi","chetna","vaish"], marks:[1,2,3]})

# %%
d
# Out:
#   <class '__main__.Names'>  <class '__main__.marks'>
# 0                    janvi                         1
# 1                   chetna                         2
# 2                    vaish                         3

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
d.rename(columns={"Names":"MRRR"})
# Out:
#   <class '__main__.Names'>  <class '__main__.marks'>
# 0                    janvi                         1
# 1                   chetna                         2
# 2                    vaish                         3

# %%
d.columns
# Out:
# Index([<class '__main__.Names'>, <class '__main__.marks'>], dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   <class '__main__.Names'>  3 non-null      object
#  1   <class '__main__.marks'>  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5 entries, a to e
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 80.0+ bytes

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   <class '__main__.Names'>  3 non-null      object
#  1   <class '__main__.marks'>  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
d.columns
# Out:
# Index(['Names', 'marks'], dtype='object')

# %%
d.columns=['Names','marks']

# %%
d.rename(columns={'MRRR':'Names'})
# Out:
#     Names  marks
# 0   janvi    1.0
# 1  chetna    2.0
# 2   vaish    3.0

# %%
d['marks']=d['marks'].astype(float)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Names   3 non-null      object
#  1   marks   3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 180.0+ bytes
